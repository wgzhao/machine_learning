# %% [markdown]
# # 1. 载入需要的库

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import rcParams
# Ignore warnings
import warnings
warnings.filterwarnings('ignore')
# display Chinese characters
rcParams['font.family'] = "FZXiHei I-Z08S"
rcParams['font.size'] = '14'

# %% [markdown]
# # 2. 数据获取

# %%
df = pd.read_csv('./train.csv', index_col=['Id'])
df_test = pd.read_csv('./test.csv', index_col=['Id'])
y = df.SalePrice
df_train = df.drop(labels=["SalePrice"], axis=1)
df_train['train_set']=True
df_test['train_set']=False
df = pd.concat([df_train, df_test])
del df_train
del df_test

# %% [markdown]
# # 3. 数据概览
# ## 3.1 数据整体情况

# %%
print("数据维度情况: ", df.shape)
#  分别列出数字类型和条目类型的特征统计情况
num_of_numerical_cols = df._get_numeric_data().columns.shape[0]
print("数字类型特征数量",num_of_numerical_cols,)
print("条目类型特征数量", df.shape[1] - num_of_numerical_cols)
print("数据摘要")
df.head(10)
# Out:
# 数据维度情况:  (2919, 80)
# 数字类型特征数量 37
# 条目类型特征数量 43
# 数据摘要
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
# 6           50       RL         85.0    14115   Pave   NaN      IR1
# 7           20       RL         75.0    10084   Pave   NaN      Reg
# 8           60       RL          NaN    10382   Pave   NaN      IR1
# 9           50       RM         51.0     6120   Pave   NaN      Reg
# 10         190       RL         50.0     7420   Pave   NaN      Reg
#
#    LandContour Utilities LotConfig    ...     PoolArea PoolQC  Fence  \
# Id                                    ...
# 1          Lvl    AllPub    Inside    ...            0    NaN    NaN
# 2          Lvl    AllPub       FR2    ...            0    NaN    NaN
# 3          Lvl    AllPub    Inside    ...            0    NaN    NaN
# 4          Lvl    AllPub    Corner    ...            0    NaN    NaN
# 5          Lvl    AllPub       FR2    ...            0    NaN    NaN
# 6          Lvl    AllPub    Inside    ...            0    NaN  MnPrv
# 7          Lvl    AllPub    Inside    ...            0    NaN    NaN
# 8          Lvl    AllPub    Corner    ...            0    NaN    NaN
# 9          Lvl    AllPub    Inside    ...            0    NaN    NaN
# 10         Lvl    AllPub    Corner    ...            0    NaN    NaN
#
#    MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition  train_set
# Id
# 1          NaN       0      2    2008        WD         Normal       True
# 2          NaN       0      5    2007        WD         Normal       True
# 3          NaN       0      9    2008        WD         Normal       True
# 4          NaN       0      2    2006        WD        Abnorml       True
# 5          NaN       0     12    2008        WD         Normal       True
# 6         Shed     700     10    2009        WD         Normal       True
# 7          NaN       0      8    2007        WD         Normal       True
# 8         Shed     350     11    2009        WD         Normal       True
# 9          NaN       0      4    2008        WD        Abnorml       True
# 10         NaN       0      1    2008        WD         Normal       True
#
# [10 rows x 80 columns]

# %% [markdown]
# ## 3.2 数据缺失情况分析

# %%
def get_missing():
    data_df_na = df.isnull().mean(axis=0)
    data_df_na = data_df_na.drop(data_df_na[data_df_na == 0].index).sort_values(ascending=False)
    missing_data = pd.DataFrame({'missing_rate': data_df_na})
    print('missing_data.shape = ', missing_data.shape)
    return missing_data
get_missing()
# Out:
# missing_data.shape =  (34, 1)
#               missing_rate
# PoolQC            0.996574
# MiscFeature       0.964029
# Alley             0.932169
# Fence             0.804385
# FireplaceQu       0.486468
# LotFrontage       0.166495
# GarageFinish      0.054471
# GarageYrBlt       0.054471
# GarageQual        0.054471
# GarageCond        0.054471
# GarageType        0.053786
# BsmtExposure      0.028092
# BsmtCond          0.028092
# BsmtQual          0.027749
# BsmtFinType2      0.027407
# BsmtFinType1      0.027064
# MasVnrType        0.008222
# MasVnrArea        0.007879
# MSZoning          0.001370
# BsmtFullBath      0.000685
# BsmtHalfBath      0.000685
# Utilities         0.000685
# Functional        0.000685
# Exterior2nd       0.000343
# Exterior1st       0.000343
# SaleType          0.000343
# BsmtFinSF1        0.000343
# BsmtFinSF2        0.000343
# BsmtUnfSF         0.000343
# Electrical        0.000343
# KitchenQual       0.000343
# GarageCars        0.000343
# GarageArea        0.000343
# TotalBsmtSF       0.000343

# %%
# 丢失可视化展现
sns.barplot(x = missing_data.index, y = 100 *missing_data.missing_rate )
plt.xticks(rotation=90)
plt.rcParams['figure.figsize'] = (18,4)
plt.xlabel('特征', fontsize=12)
plt.ylabel('丢失比', fontsize=12)
plt.title('特征数据丢失率一览图', fontsize=12)
# Out:
# Text(0.5,1,'特征数据丢失率一览图')

# %% [markdown]
# # 数据处理
# ## 4.1 填补丢失的数据

# %%
# 没有游泳池(pool)的，一律填写 None，表示无
df['PoolQC'] = df['PoolQC'].fillna('None')
df['PoolArea'] = df['PoolArea'].fillna(0)

df['MiscFeature'] = df['MiscFeature'].fillna('None')
df['Alley'] = df['Alley'].fillna('None')
df['Fence'] = df['Fence'].fillna('None')
df['FireplaceQu'] = df['FireplaceQu'].fillna('None')

# LotForntage 的填充采取 Neighboarhood 的分区平均值进行填充
df['LotFrontage'] = df.groupby('Neighborhood')['LotFrontage'].transform(
            lambda x: x.fillna(x.mean()))

# gara 车库丢失数据填充
for col in ['GarageType','GarageFinish','GarageQual','GarageCond']:
    df[col] = df[col].fillna('None')
for col in ['GarageCars','GarageArea','GarageYrBlt']:
    df[col] = df[col].fillna(0)

# basement 地下室及相关特征数据填充方法
for col in ('BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF','TotalBsmtSF', 'BsmtFullBath', 
            'BsmtHalfBath'):
    df[col] = df[col].fillna(0)
    
for col in ('BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2'):
    df[col] = df[col].fillna('None')
    
#  masonry veneer 建筑材料特征数据填充方法
df['MasVnrType'] = df['MasVnrType'].fillna('None')
df['MasVnrArea'] = df['MasVnrArea'].fillna(0)

# MSZoning 出售类型 ,按照最常用的填充
df['MSZoning'] = df['MSZoning'].fillna(df['MSZoning'].mode()[0])

# Utilities 的类型分布情况为
#AllPub    2916 NoSeWa       1
# 因此该特征可以考虑直接丢弃
df.drop(labels=['Utilities'], axis=1, inplace=True)

# Functional 房屋分类，按照通用类型填充
df['Functional'] = df['Functional'].fillna('Typ')

# Exterior1st, Exterior2nd 外层装饰材料,也采取使用最常见的类型填充
df['Exterior1st'] = df['Exterior1st'].fillna(df['Exterior1st'].mode()[0])
df['Exterior2nd'] = df['Exterior2nd'].fillna(df['Exterior2nd'].mode()[0])

# SaleType 也按照常见类型填充
df['SaleType'] = df['SaleType'].fillna(df['SaleType'].mode()[0])

#Electrical 电力系统
df['Electrical'] = df['Electrical'].fillna(df['Electrical'].mode()[0])

#KitchenQual， 字段说明里有Kitchen，但是数据里没有这个字段
df['KitchenQual'] = df['KitchenQual'].fillna(df['KitchenQual'].mode()[0])

# %% [markdown]
# ## 4.2 看是否还有丢失的数据

# %%
get_missing()
# Out:
# missing_data.shape =  (0, 1)
# Empty DataFrame
# Columns: [missing_rate]
# Index: []

# %% [markdown]
# ## 4.3 类型转换
# 对于那些用数值表示，但没有大小比较意义的特征类型，我们把数据类型强制转为字符型，这样模型不会尝试对这些值进行比较

# %%
df['MSSubClass'] = df['MSSubClass'].astype(str)
df['YearBuilt'] = df['YearBuilt'].astype(str)
df['YrSold'] = df['YrSold'].astype(str)
df['MoSold'] = df['MoSold'].astype(str)

# %% [markdown]
# ## 4.4 对条目类型特征进行 one-hot 编码

# %%
# 进行 one-hot 编码
need_onehot_cols =  ('FireplaceQu', 'BsmtQual', 'BsmtCond', 'GarageQual', 'GarageCond', 
        'ExterQual', 'ExterCond','HeatingQC', 'PoolQC', 'KitchenQual', 'BsmtFinType1', 
        'BsmtFinType2', 'Functional', 'Fence', 'BsmtExposure', 'GarageFinish', 'LandSlope',
        'LotShape', 'PavedDrive', 'Street', 'Alley', 'CentralAir', 'MSSubClass', 'OverallCond', 
        'YrSold', 'MoSold')
for col in need_onehot_cols:
    dummies =  pd.get_dummies(df[col], prefix=col)
    df = pd.concat([df, dummies], axis=1)
    del df[col]
df.head()
# Out:
#    MSZoning  LotFrontage  LotArea LandContour LotConfig Neighborhood  \
# Id
# 1        RL         65.0     8450         Lvl    Inside      CollgCr
# 2        RL         80.0     9600         Lvl       FR2      Veenker
# 3        RL         68.0    11250         Lvl    Inside      CollgCr
# 4        RL         60.0     9550         Lvl    Corner      Crawfor
# 5        RL         84.0    14260         Lvl       FR2      NoRidge
#
#    Condition1 Condition2 BldgType HouseStyle   ...     MoSold_11 MoSold_12  \
# Id                                             ...
# 1        Norm       Norm     1Fam     2Story   ...             0         0
# 2       Feedr       Norm     1Fam     1Story   ...             0         0
# 3        Norm       Norm     1Fam     2Story   ...             0         0
# 4        Norm       Norm     1Fam     2Story   ...             0         0
# 5        Norm       Norm     1Fam     2Story   ...             0         1
#
#     MoSold_2 MoSold_3 MoSold_4 MoSold_5 MoSold_6 MoSold_7  MoSold_8 MoSold_9
# Id
# 1          1        0        0        0        0        0         0        0
# 2          0        0        0        1        0        0         0        0
# 3          0        0        0        0        0        0         0        1
# 4          1        0        0        0        0        0         0        0
# 5          0        0        0        0        0        0         0        0
#
# [5 rows x 197 columns]

# %% [markdown]
# ## 4.5 增加特征向量
# 我们增加一个房屋总面积的特征向量

# %%
df['totalSF'] = df['TotalBsmtSF'] + df['1stFlrSF'] + df['2ndFlrSF']

# %% [markdown]
# ## 4.6 数据拆分

# %%
# 拆分数据集
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import BaggingRegressor
df_train = df[df_full['train_set'] == True]
df_test = df[df_full['train_set' ] == False]
df_train.drop(labels=['train_set'], axis=1, inplace=True)
df_test.drop(labels=['train_set'],axis=1, inplace=True)
X_train, X_test,y_train,y_test = train_test_split(df_train, y, test_size=0.2, random_state=0)
print("训练数据集:", X_train.shape)
print("校验数据集", X_test.shape)
# Out:
# 训练数据集: (1168, 197)
# 校验数据集 (292, 197)

# %% [markdown]
# # 5. 创建模型
#
# 我们尝试创建不同的模型，来检测看哪个模型的效果更好
#
# ## 5.1  梯度增强模型

# %%
gboost = GradientBoostingRegressor(random_state=0,
                learning_rate=0.015, 
                min_samples_split=2,
                n_estimators=1000,
                min_samples_leaf=1,
                subsample=0.2)
gboost.fit(X_train,y_train)
gboost.score(X_test,y_test)
# Out:
# 0.8707637778086001

# %% [markdown]
# ## 5.2 随机森林模型

# %%
rfr = RandomForestRegressor(n_estimators=1000, random_state=0)
model_br.fit(X_train, y_train)
model_br.score(X_test, y_test)
# Out:
#                    feature     score
# 14               GrLivArea  0.110672
# 10             TotalBsmtSF  0.095338
# 9                BsmtUnfSF  0.079320
# 11                1stFlrSF  0.076406
# 7               BsmtFinSF1  0.073083
# 2              OverallQual  0.052852
# 1                  LotArea  0.040605
# 12                2ndFlrSF  0.031454
# 25              GarageArea  0.031425
# 4                YearBuilt  0.021178
# 111        Condition2_PosN  0.020956
# 0              LotFrontage  0.017437
# 6               MasVnrArea  0.017016
# 27             OpenPorchSF  0.016626
# 3              OverallCond  0.016394
# 5             YearRemodAdd  0.014268
# 21            TotRmsAbvGrd  0.013030
# 23             GarageYrBlt  0.011798
# 26              WoodDeckSF  0.011686
# 79    Neighborhood_Crawfor  0.009848
# 141       RoofMatl_WdShngl  0.009539
# 32                  MoSold  0.008717
# 19            BedroomAbvGr  0.008670
# 17                FullBath  0.007924
# 28           EnclosedPorch  0.007694
# 128         RoofStyle_Flat  0.006688
# 206          KitchenQual_9  0.006277
# 30             ScreenPorch  0.006275
# 8               BsmtFinSF2  0.005392
# 15            BsmtFullBath  0.005252
# ..                     ...       ...
# 228           GarageQual_2  0.000000
# 229           GarageQual_3  0.000000
# 191            HeatingQC_2  0.000000
# 185          Heating_Floor  0.000000
# 188           Heating_Grav  0.000000
# 190           Heating_Wall  0.000000
# 121      HouseStyle_1.5Unf  0.000000
# 126      HouseStyle_SFoyer  0.000000
# 68           LotConfig_FR3  0.000000
# 59            LotShape_IR3  0.000000
# 36            MSSubClass_C  0.000000
# 37            MSSubClass_D  0.000000
# 42            MSSubClass_I  0.000000
# 43            MSSubClass_J  0.000000
# 46            MSSubClass_M  0.000000
# 47            MSSubClass_N  0.000000
# 48            MSSubClass_O  0.000000
# 52             MSZoning_RH  0.000000
# 74    Neighborhood_Blueste  0.000000
# 75     Neighborhood_BrDale  0.000000
# 83    Neighborhood_MeadowV  0.000000
# 86    Neighborhood_NPkVill  0.000000
# 97    Neighborhood_Veenker  0.000000
# 134       RoofMatl_ClyTile  0.000000
# 137         RoofMatl_Metal  0.000000
# 138          RoofMatl_Roll  0.000000
# 140       RoofMatl_WdShake  0.000000
# 133         RoofStyle_Shed  0.000000
# 242  SaleCondition_AdjLand  0.000000
# 55             Street_Grvl  0.000000
#
# [247 rows x 2 columns]

# %%
# predictions = model_gbr.predict(df_test)
# my_submission = pd.DataFrame({'Id': df_test.index, 'SalePrice': predictions})
# my_submission.to_csv('./house_price_pred.csv', index=False)
