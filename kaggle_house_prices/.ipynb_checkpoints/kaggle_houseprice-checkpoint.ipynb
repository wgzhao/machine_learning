# %% [markdown]
# # 1. 载入需要的库

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import rcParams
# Ignore warnings
import warnings
warnings.filterwarnings('ignore')
# display Chinese characters
rcParams['font.family'] = "FZXiHei I-Z08S"
rcParams['font.size'] = '14'
rcParams['figure.figsize'] = 16,4
sns.set_style('white')

# %% [markdown]
# # 2. 数据获取

# %%
df_train = pd.read_csv('./data/train.csv', index_col=['Id'])
df_test = pd.read_csv('./data/test.csv', index_col=['Id'])
y = df_train.SalePrice
df_test['SalePrice'] = 0.0
df = df_train.append(df_test)

# %% [markdown]
# # 3. 数据概览
# ## 3.1 数据整体情况

# %%
print("数据维度情况: ", df.shape)
#  分别列出数字类型和条目类型的特征统计情况
num_of_numerical_cols = df._get_numeric_data().columns.shape[0]
print("数字类型特征数量",num_of_numerical_cols,)
print("条目类型特征数量", df.shape[1] - num_of_numerical_cols)
print("数据摘要")
df.head(10)
# Out:
# 数据维度情况:  (2919, 80)
# 数字类型特征数量 37
# 条目类型特征数量 43
# 数据摘要
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
# 6           50       RL         85.0    14115   Pave   NaN      IR1
# 7           20       RL         75.0    10084   Pave   NaN      Reg
# 8           60       RL          NaN    10382   Pave   NaN      IR1
# 9           50       RM         51.0     6120   Pave   NaN      Reg
# 10         190       RL         50.0     7420   Pave   NaN      Reg
#
#    LandContour Utilities LotConfig    ...     PoolArea PoolQC  Fence  \
# Id                                    ...
# ...

# %% [markdown]
# ## 3.2 数据缺失情况分析

# %%
def get_missing(data):
    data_df_na = data.isnull().mean(axis=0)
    data_df_na = data_df_na.drop(data_df_na[data_df_na == 0].index).sort_values(ascending=False)
    missing_data = pd.DataFrame({'missing_rate': data_df_na})
    print('missing_data.shape = ', missing_data.shape)
    return missing_data

print(get_missing(df))
# Out:
# missing_data.shape =  (34, 1)
#               missing_rate
# PoolQC            0.996574
# MiscFeature       0.964029
# Alley             0.932169
# Fence             0.804385
# FireplaceQu       0.486468
# LotFrontage       0.166495
# GarageFinish      0.054471
# GarageYrBlt       0.054471
# GarageQual        0.054471
# GarageCond        0.054471
# GarageType        0.053786
# BsmtExposure      0.028092
# BsmtCond          0.028092
# BsmtQual          0.027749
# BsmtFinType2      0.027407
# BsmtFinType1      0.027064
# MasVnrType        0.008222
# MasVnrArea        0.007879
# MSZoning          0.001370
# BsmtFullBath      0.000685
# BsmtHalfBath      0.000685
# Utilities         0.000685
# Functional        0.000685
# Exterior2nd       0.000343
# Exterior1st       0.000343
# SaleType          0.000343
# BsmtFinSF1        0.000343
# BsmtFinSF2        0.000343
# BsmtUnfSF         0.000343
# Electrical        0.000343
# KitchenQual       0.000343
# GarageCars        0.000343
# ...

# %%
# 丢失可视化展现
missing_data = get_missing(df)
sns.barplot(x = missing_data.index, y = 100 *missing_data.missing_rate )
plt.xticks(rotation=90)
plt.rcParams['figure.figsize'] = (18,4)
plt.xlabel('特征', fontsize=12)
plt.ylabel('丢失比', fontsize=12)
plt.title('特征数据丢失率一览图', fontsize=12)
# Out:
# missing_data.shape =  (34, 1)
# Text(0.5,1,'特征数据丢失率一览图')

# %% [markdown]
# # 数据处理
# ## 4.1 填补丢失的数据

# %%
# 没有游泳池(pool)的，一律填写 None，表示无
df['PoolQC'] = df['PoolQC'].fillna('None')
df['PoolArea'] = df['PoolArea'].fillna(0)

df['MiscFeature'] = df['MiscFeature'].fillna('None')
df['Alley'] = df['Alley'].fillna('None')
df['Fence'] = df['Fence'].fillna('None')
df['FireplaceQu'] = df['FireplaceQu'].fillna('None')

# LotForntage 的填充采取 Neighboarhood 的分区平均值进行填充
df['LotFrontage'] = df.groupby('Neighborhood')['LotFrontage'].transform(
            lambda x: x.fillna(x.mean()))

# gara 车库缺失数据填充
for col in ['GarageType','GarageFinish','GarageQual','GarageCond']:
    df[col] = df[col].fillna('None')
for col in ['GarageCars','GarageArea','GarageYrBlt']:
    df[col] = df[col].fillna(0)

# basement 地下室及相关特征数据填充方法
for col in ('BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF','TotalBsmtSF', 'BsmtFullBath', 
            'BsmtHalfBath'):
    df[col] = df[col].fillna(0)
    
for col in ('BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2'):
    df[col] = df[col].fillna('None')
    
#  masonry veneer 建筑材料特征数据填充方法
df['MasVnrType'] = df['MasVnrType'].fillna('None')
df['MasVnrArea'] = df['MasVnrArea'].fillna(0)

# MSZoning 出售类型 ,按照最常用的填充
df['MSZoning'] = df['MSZoning'].fillna(df['MSZoning'].mode()[0])

# Utilities 的类型分布情况为
#AllPub    2916 NoSeWa       1
# 因此该特征可以考虑直接丢弃
df.drop(labels=['Utilities'], axis=1, inplace=True)

# Functional 房屋分类，按照通用类型填充
df['Functional'] = df['Functional'].fillna('Typ')

# Exterior1st, Exterior2nd 外层装饰材料,也采取使用最常见的类型填充
df['Exterior1st'] = df['Exterior1st'].fillna(df['Exterior1st'].mode()[0])
df['Exterior2nd'] = df['Exterior2nd'].fillna(df['Exterior2nd'].mode()[0])

# SaleType 也按照常见类型填充
df['SaleType'] = df['SaleType'].fillna(df['SaleType'].mode()[0])

#Electrical 电力系统
df['Electrical'] = df['Electrical'].fillna(df['Electrical'].mode()[0])

#KitchenQual， 字段说明里有Kitchen，但是数据里没有这个字段
df['KitchenQual'] = df['KitchenQual'].fillna(df['KitchenQual'].mode()[0])

# %% [markdown]
# ## 4.2 看是否还有丢失的数据

# %%
print(get_missing(df))
# Out:
# missing_data.shape =  (0, 1)
# Empty DataFrame
# Columns: [missing_rate]
# Index: []

# %% [markdown]
# ## 4.3 类型转换
# 对于那些用数值表示，但没有大小比较意义的特征类型，我们把数据类型强制转为字符型，这样模型不会尝试对这些值进行比较

# %%
df['MSSubClass'] = df['MSSubClass'].astype(str)
df['YearBuilt'] = df['YearBuilt'].astype(str)
df['YrSold'] = df['YrSold'].astype(str)
df['MoSold'] = df['MoSold'].astype(str)

# %%
print("条目类特征列表：", df.select_dtypes(['object']).columns.tolist())
print("数值类特征列表：", df.select_dtypes(['int','float']).columns.tolist())
# Out:
# 条目类特征列表： ['MSSubClass', 'MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'YearBuilt', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'MoSold', 'YrSold', 'SaleType', 'SaleCondition']
# ...

# %% [markdown]
# ## 4.4 对条目类型特征进行 one-hot 编码

# %%
lb = LabelEncoder()
need_onehot_cols =  ['MSSubClass', 'MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'LotConfig', 
                     'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 
                     'YearBuilt', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 
                     'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 
                     'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 
                     'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 
                     'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'MoSold', 'YrSold', 
                     'SaleType', 'SaleCondition']
for col in need_onehot_cols:
    df[col] = lb.fit_transform(df[col])

# %% [markdown]
# ## 4.5 增加特征向量
# 我们增加一个房屋总面积的特征向量

# %%
df['totalSF'] = df['TotalBsmtSF'] + df['1stFlrSF'] + df['2ndFlrSF']
df['totalSF'].head(10)
# Out:
# Id
# 1     2566.0
# 2     2524.0
# 3     2706.0
# 4     2473.0
# 5     3343.0
# 6     2158.0
# 7     3380.0
# 8     3197.0
# 9     2726.0
# 10    2068.0
# Name: totalSF, dtype: float64

# %%
# 检查数值类型特征的倾斜度
import scipy
numerical_cols = df.select_dtypes(['float','int']).columns
skewness_of_cols = {}
for col in numerical_cols:
    skewness_of_cols[col] = scipy.stats.skew(df[col].dropna())
# skewness_of_cols = df[num_of_numerical_cols].apply(
#                     lambda x:scipy.stats.skew(x)).sort_values(
#                     ascending=False)
skewness_df = pd.DataFrame({'Skewness': skewness_of_cols})
skewness_df.sort_values(['Skewness'], ascending=0, inplace=True)
skewness_df.head(10)
# Out:
#                Skewness
# MiscVal       21.947195
# PoolArea      16.898328
# LotArea       12.822431
# LowQualFinSF  12.088761
# Heating       12.078788
# Condition2    12.060093
# 3SsnPorch     11.376065
# RoofMatl       8.707767
# MiscFeature    5.064321
# LandSlope      4.975157

# %%
sns.distplot(df.PoolArea[df.PoolArea > 0], kde=True)
#sns.distplot(scipy.special.boxcox1p(df.PoolArea, 0.1), kde=True)

# %%
# 对偏离度较高的特征进行 Box-Cox 调整
skewness_df = skewness_df[abs(skewness_df) > 0.75]
print("skewness shape = ", skewness_df.shape)
cols = skewness_df.index
lamb = 0.15
for col in cols:
    df[col] = scipy.special.boxcox1p(df[col], lamb)
# Out:
# skewness shape =  (80, 1)

# %%
# 再次检查偏离度
numerical_cols = df.select_dtypes(['float','int']).columns
skewness_of_cols = {}
for col in numerical_cols:
    skewness_of_cols[col] = scipy.stats.skew(df[col].dropna())
# skewness_of_cols = df[num_of_numerical_cols].apply(
#                     lambda x:scipy.stats.skew(x)).sort_values(
#                     ascending=False)
skewness_df = pd.DataFrame({'Skewness': skewness_of_cols})
skewness_df.sort_values(['Skewness'], ascending=0, inplace=True)
skewness_df.head(10)
# Out:
#                Skewness
# PoolArea      15.119426
# Heating        9.972171
# 3SsnPorch      8.924822
# LowQualFinSF   8.744143
# RoofMatl       8.325609
# MiscVal        5.597060
# MiscFeature    4.642747
# LandSlope      4.532036
# BsmtHalfBath   3.788243
# KitchenAbvGr   3.698825

# %% [markdown]
# ## 4.6 对数值型数据做规整化

# %%
from sklearn.preprocessing import RobustScaler
def normalize_data(data): 
    # scale features using statistics that are robust to outliers
    # turns out that sklearn works very well 
    rs = RobustScaler()
    rs.fit(data)
    data = rs.transform(data)
    #div = np.percentile(data,0.75,axis=0) - np.percentile(data,0.25,axis=0)
    #np.place(div, div < 1., 1.)
    #print(div)
    #data = (data-np.median(data,axis=0))/div
    return data

choose_cols=['LotArea', 'LotFrontage', 'totalSF', 'MSSubClass', 'GarageArea', 'TotalBsmtSF',
             'GrLivArea', 'Neighborhood', 'YearRemodAdd', 'OverallCond', 'HeatingQC',
             'OpenPorchSF', 'Condition1', 'MSZoning', 'OverallQual', 'WoodDeckSF','PoolQC',
            'ExterQual','Alley','GarageQual','FireplaceQu','RoofStyle']
choose_cols2 = ['LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 
               'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 
                'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 
               'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal']
choose_catggories = ['MSSubClass', 'MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'LotConfig', 'LandSlope', 'Neighborhood', 
                     'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'YearBuilt', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd',
                     'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 
                     'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 
                     'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'MoSold', 'YrSold', 'SaleType', 'SaleCondition']
df_train = df[df.SalePrice >0.0]
df_test = df[df.SalePrice  == 0.0]
# df_train.drop(labels=['SalePrice'], axis=1, inplace=True)
# df_test.drop(labels=['SalePrice'],axis=1, inplace=True)
df_train = df_train[choose_catggories]
df_test = df_test[choose_catggories]
X_train = normalize_data(df_train)
df_test = normalize_data(df_test)
y_train = np.log1p(y)

# %% [markdown]
# ## 4.6 数据拆分

# %%
# 拆分数据集
from sklearn.model_selection import train_test_split
X_train, X_test,y_train,y_test = train_test_split(X_train, y_train, test_size=0.1, random_state=0)
print("训练数据集:", X_train.shape)
print("校验数据集", X_test.shape)
# Out:
# 训练数据集: (1314, 32)
# 校验数据集 (146, 32)

# %% [markdown]
# # 5. 创建模型
#
# 我们尝试创建不同的模型，然后将模型进行堆叠
#
# ## 5.1 创建可能的线性回归模型

# %%
from sklearn.ensemble import AdaBoostRegressor, GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import ElasticNet, LinearRegression, Lasso
from sklearn.neural_network import MLPRegressor
from xgboost import XGBRegressor
gdm = XGBRegressor(n_estimators=500, learning_rate=0.1, max_features='sqrt',
                                   max_depth=4, min_samples_leaf=15, min_samples_split=10, 
                                   loss='huber', random_state =0)
rfr = RandomForestRegressor(n_estimators=500,
                           max_depth=4, max_features='sqrt',
                           min_samples_leaf=15, min_samples_split=10, 
                           random_state =0)
lasso = Lasso(alpha = 0.0005, random_state=1)
enet = ElasticNet(alpha=0.0005, l1_ratio=.9, random_state=3)
linreg = LinearRegression()
nn = MLPRegressor(hidden_layer_sizes = (90, 90),alpha = 2.75)
adboost = AdaBoostRegressor(n_estimators=500, learning_rate=0.1, 
                            loss='square', random_state=0)

# %% [markdown]
# ## 5.2 模型集成

# %%
from mlxtend.regressor import StackingRegressor
from sklearn.metrics import mean_squared_error
from sklearn.externals import joblib
from sklearn.cross_validation import cross_val_score
models = {'XGBoost': gdm , 'RandomForest': rfr, 'LASSO': lasso, 'ENET':enet, 'Adaboost': adboost}

print("搜索最佳模型")
# for name, model in models.items():
#     scores = cross_val_score(model, X_train ,y_train, cv=5)
#     print("{} Accuracy: {:.2f} (+/- {:.2f})".format(name, scores.mean(), scores.std() * 2))
# y_pred = model.predict(X_train)        
# # 拟合结果的评估和可视化
# print("Mean Squared Error: %.4f" % get_rmse(y_pred, y_train))
# print('Variance Score: %.4f' % model.score(X_test, y_test))
# Out:
# 搜索最佳模型

# %%
gdm.fit(X_train, y_train)
y_pred_train = gdm.predict(X_train)
y_pred_valid = gdm.predict(X_test)
print("XGBoost train RMSE score:", np.sqrt(np.mean((y_train - y_pred_train)**2)))
print("XGBoost valid RMSE score:", np.sqrt(np.mean((y_test - y_pred_valid)**2)))
# Out:
# XGBoost train RMSE score: 0.028247957389237216
# XGBoost valid RMSE score: 0.14125249219246977

# %%
features_imp = pd.DataFrame({'feature': df_train.columns, 'importance': gdm.feature_importances_})
features_imp.sort_values('importance', ascending=False, inplace=True)
features_imp[features_imp.importance >0.02]
# Out:
#          feature  importance
# 0    LotFrontage    0.112730
# 1        LotArea    0.097500
# 13     GrLivArea    0.074491
# 8      BsmtUnfSF    0.073498
# 9    TotalBsmtSF    0.057937
# 24    GarageArea    0.056448
# 4   YearRemodAdd    0.052806
# 22   GarageYrBlt    0.049661
# 10      1stFlrSF    0.046847
# 6     BsmtFinSF1    0.045026
# 2    OverallQual    0.043370
# 5     MasVnrArea    0.032942
# 26   OpenPorchSF    0.032279
# 25    WoodDeckSF    0.030624
# 11      2ndFlrSF    0.028969
# 3    OverallCond    0.025492

# %%
predictions = gdm.predict(df_test)
my_submission = pd.DataFrame({'Id': range(1461,2920), 'SalePrice':  np.expm1(predictions)})
my_submission.to_csv('./house_price_pred.csv', index=False)
my_submission.tail()
# Out:
#         Id      SalePrice
# 1454  2915   78482.460938
# 1455  2916   94405.312500
# 1456  2917  176155.031250
# 1457  2918  117471.632812
# 1458  2919  236427.625000
